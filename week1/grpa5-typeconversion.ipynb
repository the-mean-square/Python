# %% [markdown]
# ### I/0 & Type Conversions

# %%
age = int(input("Enter your age: ")) # int: Read a number as integer from standard input
dob = str(input("Enter your dob in dd/mm/yyyy format: ")) # str: Read a string of format dd/mm/yy from standard input
day, month, year = int(dob[:2]), int(dob[3:5]), int(dob[6:]) # int, int, int: Get the correct parts from dob as int

fifth_birthday = str(day)+'/'+str(month)+'/'+str(year+5)  # str: fifth birthday formatted as day/month/year 

last_birthday = str(day)+'/'+str(month)+'/'+str(year+age) # str: last birthday formatted as day/month/year

# catch
# find tenth_month = ... # str: dob same day after 10 months formatted as day/month/year

month += 10
month, year = (month-1)%12+1, year+(month-1)//12
tenth_month = str(day)+"/"+str(month)+"/"+str(year) # str: dob same day after 10 months formatted as day/month/year



# print tenth_month, fifth_birthday and last_birthday in same line separated by comma and a space
print("Your fifth birthday was on ", fifth_birthday, "and ",  "your last birthday was on ", last_birthday)

print("Ten months later birthday is : ",tenth_month)
# Out:
# Your fifth birthday was on  29/1/1998 and  your last birthday was on  29/1/2025
# Ten months later birthday is :  29/11/1993

# %%
weight = float(input("Enter your weight in decimals")) # float: Read a number as float from stdin(Standard input)
kg = int(weight)
gms =int((weight-kg)*1000)
weight_readable = str(kg) + " kg, " + str(gms) + " gms " # str: reformat weight of format 55 kg 250 grams

# print weight_readable 
print("Your weight is :",  weight_readable)
# Out:
# Your weight is : 69 kg, 950 gms
