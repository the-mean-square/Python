# %% [markdown]
# #### Sum of squares and absolute difference of squares

# %%
def sum_squares_abs_diff_squares(a:int, b:int) -> tuple:
    '''Return the sum of squares and the absolute difference of squares.

    Args:
        a, b : int - input numbers

    Returns:
        tuple - tuple with sum of squares and absolute difference of squares.

    '''
    sum_squares =(a*a)+(b*b)
    abs_difference = abs((a*a)-(b*b))
    return (sum_squares, abs_difference)

# %% [markdown]
# #### Is Odd-Length Palindrome

# %%
def is_odd_length_palindrome(s: str) -> bool:
    '''Check if a string is a palindrome with odd length.

    Args:
        s : str - input string

    Returns:
        bool - True if s is a palindrome with odd length, False otherwise.
    '''
    
    return len(s) % 2 == 1 and s == s[::-1]

# %%
def is_odd_length_palindrome(s: str) -> bool:
    '''Check if a string is a palindrome with odd length.

    Args:
        s : str - input string

    Returns:
        bool - True if s is a palindrome with odd length, False otherwise.
    '''
    #s = str(input("enter palindrome"))
    if len(s)%2!=0:
        if s==s[::-1]:
            return True
    return False

# %% [markdown]
# #### Remove elements at given two indices of a list

# %%
def remove_elements_at_two_indices(l: list, i1: int, i2: int):
    '''Remove elements at two specified indices in the list.

    Args:
        l : list - input list
        i1, i2 : int - indices of elements to remove
            both are non-negative and unique

    Returns:
        None - modifies the list in place
    '''
    
    i1, i2 = sorted([i1, i2], reverse=True)
    del l[i1]
    del l[i2]

# %% [markdown]
# #### Sum of Squares of Even Numbers

# %%
def sum_of_squares_of_even(nums: list) -> int:
    '''Return the sum of squares of all even numbers in the list.

    Args:
        nums : list - list of integers

    Returns:
        int - sum of squares of all even numbers
    '''
    #say nums = [1,2,3,4,5,6]

    total = 0
    for num in nums:
        if num%2==0:
            total+=num*num
    return total

# %%
sum_of_squares_of_even([1,2,3,4,5,6])

# %% [markdown]
# #### Upper Case Only Vowels

# %%
n = int(input("Enter no of lines:"))

for i in range(n):
    passage = input("Enter your passages")
    fixed_passage = ""
    for j in passage:
        if j in {'a','e','i','o','u', 'A', 'E', 'I', 'O', 'U'}:
            fixed_passage+=j.upper()
        else:
            fixed_passage+=j.lower()
    print(fixed_passage)
# Out:
# hEllO wOrld

# %% [markdown]
# #### Student Marks Filter

# %%
def get_roll_nos(data:list, criteria=None):
    '''
    Filter roll numbers based on criteria.

    Args:
        data (list): List of tuples with roll number and marks.
        criteria (str, optional): The criteria for filtering.

    Returns:
        list: List of roll numbers matching the criteria or None if invalid criteria.
    '''
    ...
    #your code here
    #example
    #data = [('1',90), ('2',56), ('3',67)....]
    #criteria = "Fail", etc

    # method 1 - single function
    if criteria is None:
        return [roll_no for roll_no, _ in data]
    if criteria == 'fail':
        return [roll_no for roll_no, marks in data if marks<40]
    if criteria == 'toppers':
        return [roll_no for roll_no, marks in data if marks>=90]

    marks = [row[1] for row in data]
    avg = sum(marks)/len(marks)
    if criteria == 'above_average':
        return [roll_no for roll_no, marks in data if marks>=avg]
    if criteria == 'below_average':
        return [roll_no for roll_no, marks in data if marks<avg]

# %%
data = [('101', 85), ('102', 75), ('103', 45), ('104', 95), ('105', 35)]
print(get_roll_nos(data, 'above_average'))
print(get_roll_nos(data, 'fail'))
print(get_roll_nos(data, 'bla-bla'))
print(get_roll_nos(data, None))
# Out:
# ['101', '102', '104']
# ['105']
# None
# ['101', '102', '103', '104', '105']

# %% [markdown]
# #### Print Pattern - V

# %%
n = int(input("Enter no of v's"))
for i in range(n-1):
    print(f"{' '*i}\\{' '*(2*(n-i)-3)}/")
print(' '*(n-1)+'v')
# Out:
# \         /
#  \       /
#   \     /
#    \   /
#     \ /
#      v

# %% [markdown]
# #### Check Positive Odd or Negative Even

# %%
def is_positive_odd_or_negative_even(n: int) -> bool:
    '''Check if the number is a positive odd or a negative even.

    Args:
        n : int - input integer

    Returns:
        bool - True if positive odd or negative even, else False

    '''
    #n = int(input("Enter a number"))
    if n == 0:
        print("False")
    elif (n>0 and n%2!=0) or (n<0 and n%2==0):
        print("True")
    else:
        print("False")

# %%
is_positive_odd_or_negative_even(-2)
# Out:
# True

# %%
def is_positive_odd_or_negative_even(n: int) -> bool:
    '''Check if the number is a positive odd or a negative even.

    Args:
        n : int - input integer

    Returns:
        bool - True if positive odd or negative even, else False
    '''
    
    return (n % 2 != 0 and n > 0) or (n % 2 == 0 and n < 0)

# %%
is_positive_odd_or_negative_even(-1)
# Out:
# False

# %% [markdown]
# #### Check if the Given String is Within Quotes and Has Quotes Inside

# %%
def within_and_has_double_quotes(s: str) -> bool:
    '''Check if the string is enclosed with double quotes and has double quotes inside.

    Args:
        s : str - input string

    Returns:
        bool - True if the string starts and ends with double quotes and has double quotes inside
    '''
    
    return s[0] == s[-1] == '"' and '"' in s[1:-1]

# %%
within_and_has_double_quotes("abcd\"efgh")
# Out:
# False

# %% [markdown]
# #### Count Positive Integers Ignoring None

# %%
def count_positive_ignore_none(nums: list):
    '''
    Count the number of positive integers in the list, ignoring `None` values and zeros.

    Args:
        nums (list): A list of numbers, possibly containing `None` values.

    Returns:
        int: The count of positive integers in the list.
    '''
    
    
    # 1 - Basic method
    count =0
    for num in nums:
        if num is not None and num>0:
            count += 1
    return count

# %%
count_positive_ignore_none([1,-1,0,8,9, None, 10])
# Out:
# 4

# %% [markdown]
# #### Find Sum and Absolute Difference Alternately

# %%
n = int(input("Enter number of pairs:"))

for i in range(n):
    a,b = input().split(',')
    a,b = int(a), int(b)
    if i%2==0:
        print(a+b)
    else:
        print(abs(a-b))
# Out:
# 3
# 1
# 3

# %% [markdown]
# #### Matrix Walk

# %%
M = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
def walk_L(M):
    path = []
    m = len(M)
    for i in range(m):
        path.append(M[i][0])
    for i in range(1, m):
        path.append(M[m-1][i])
    return path

def walk_Z(M):
    path = []
    m = len(M)
    for i in range(m):
        path.append(M[0][i])
    for i in range(1, m):
        path.append(M[i][m-i-1])
    for i in range(1, m):
        path.append(M[m-1][i])
    return path

def walk_O(M):
    path = []
    m = len(M)
    for i in range(m):
        path.append(M[0][i])
    for i in range(1, m):
        path.append(M[i][m-1])
    for i in range(m-2, -1, -1):
        path.append(M[m-1][i])
    for i in range(m-2, 0, -1):
        path.append(M[i][0])
    return path


def walk_matrix(M, shape):
    """
    Walk along the matrix M according to the specified shape and return the path.

    Args:
        M (list of lists): The square matrix.
        shape (str): Path shape, one of "L", "O", or "Z".

    Returns:
        list: Path along the matrix according to the shape.
    """
    
    
    if shape == 'L':
        return walk_L(M)
    elif shape == 'Z':
        return walk_Z(M)
    elif shape == 'O':
        return walk_O(M)
    else:
        return None

# %%
walk_matrix(M, 'L')
# Out:
# [1, 4, 7, 8, 9]

# %% [markdown]
# #### Print Pattern - X

# %%
n = int(input())
for i in range(n):
    print(f"{' '*i}\\{' '*(2*(n-i)-1)}/")
print(f"{' '*n}x")
for i in range(n-1,-1,-1):
    print(f"{' '*i}/{' '*(2*(n-i)-1)}\\")
# Out:
# \   /
#  \ /
#   x
#  / \
# /   \

# %% [markdown]
# #### Generic Code

# %% [markdown]
# # M

# %%
n=int(input("Enter number:"))
space_before=0
space_after=0
space_btw=2*(n-1)
for i in range(n):
     print("|"+(" "*space_before)+"\\"+(" "*space_btw)+"/"+(" "*space_after)+"|")
     space_before+=1
     space_after+=1
     space_btw-=2
# Out:
# |\  /|
# | \/ |

# %% [markdown]
# # V

# %%
n=int(input())
space_before=0
space_after=0
space_btw=2*(n-1)
for i in range(n):
     print((" "*space_before)+"\\"+(" "*space_btw)+"/"+(" "*space_after))
     space_before+=1
     space_after+=1
     space_btw-=2
# Out:
# \  /
#  \/
